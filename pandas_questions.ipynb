# %%
# Question 1 - How to import pandas and check the version
import pandas as pd
print(pd.__version__)
# Out:
# 1.5.0

# %%
# Question 2 - How to create a series from a list, numpy array and dict
import numpy as np
mylist = list('abcedfghijklmnopqrstuvwxyz')
myarr = np.arange(26)
mydict = dict(zip(mylist, myarr))

series1 = pd.Series(data=mylist)
series2 = pd.Series(data=myarr)
series3 = pd.Series(data=mydict)

print(series3)
# Out:
# a     0
# b     1
# c     2
# e     3
# d     4
# f     5
# g     6
# h     7
# i     8
# j     9
# k    10
# l    11
# m    12
# n    13
# o    14
# p    15
# q    16
# r    17
# s    18
# t    19
# u    20
# v    21
# w    22
# x    23
# y    24
# z    25
# dtype: int64

# %%
# Question 3 - How to convert the index of a series into a column of a dataframe?
mylist = list('abcedfghijklmnopqrstuvwxyz')
myarr = np.arange(26)
mydict = dict(zip(mylist, myarr))
ser = pd.Series(mydict)

# Create a df where the index and data of series are columns
df = ser.to_frame().reset_index()
df
# Out:
#    index   0
# 0      a   0
# 1      b   1
# 2      c   2
# 3      e   3
# 4      d   4
# 5      f   5
# 6      g   6
# 7      h   7
# 8      i   8
# 9      j   9
# 10     k  10
# 11     l  11
# 12     m  12
# 13     n  13
# 14     o  14
# 15     p  15
# 16     q  16
# 17     r  17
# 18     s  18
# 19     t  19
# 20     u  20
# 21     v  21
# 22     w  22
# 23     x  23
# 24     y  24
# 25     z  25

# %%
# Question 3 - How to combine many series to form a dataframe?
ser1 = pd.Series(list('abcedfghijklmnopqrstuvwxyz'))
ser2 = pd.Series(np.arange(26))
df2 = pd.concat([ser1, ser2], axis=1)
df2
# Out:
#     0   1
# 0   a   0
# 1   b   1
# 2   c   2
# 3   e   3
# 4   d   4
# 5   f   5
# 6   g   6
# 7   h   7
# 8   i   8
# 9   j   9
# 10  k  10
# 11  l  11
# 12  m  12
# 13  n  13
# 14  o  14
# 15  p  15
# 16  q  16
# 17  r  17
# 18  s  18
# 19  t  19
# 20  u  20
# 21  v  21
# 22  w  22
# 23  x  23
# 24  y  24
# 25  z  25
